# %%
import pandas as pd
import numpy as np
df = pd.read_json('..\data\\raw_sources\data_bike_exchange.json', lines=True)
df
# Out:
#                                                   Title  \
# 0            2018 Heavily Upgraded Cannondale Jekyll 2
# 1                   Specialized Enduro Fsr Comp 29 2016
# 2                             Giant Anthem SX 27.5 2016
# 3        Cannondale Trigger 27.5 Carbon Black Inc. 2015
# 4                                 Haro Shift R9 LT 2017
# ...                                                 ...
# 1977               Specialized Venge Pro Disc Udi2 2020
# 1978                           Bianchi Intenso 105 2019
# 1979              Cannondale Synaspe Carbon 5 105  2016
# 1980            Flite 900 Xl Matte Blk 2017  KHS/Maxxis
# 1981  Pinarello Dogma F10 Sulfur Yellow Custom Build...
#
#                                             Product URL      Price now  \
# 0     https://www.bikeexchange.com/a/full-suspension...         $3,250
# 1     https://www.bikeexchange.com/a/full-suspension...     Now $3,500
# 2     https://www.bikeexchange.com/a/full-suspension...  Now $1,799.99
# 3     https://www.bikeexchange.com/a/full-suspension...  Now $6,999.99
# 4     https://www.bikeexchange.com/a/full-suspension...  Now $1,699.99
# ...                                                 ...            ...
# 1977  https://www.bikeexchange.com/a/road-bikes/spec...         $8,000
# 1978  https://www.bikeexchange.com/a/road-bikes/bian...         $2,200
# 1979  https://www.bikeexchange.com/a/road-bikes/cann...      $2,099.99
# 1980  https://www.bikeexchange.com/a/road-bikes/khs/...         $3,069
# 1981  https://www.bikeexchange.com/a/road-bikes/pina...      $7,499.99
#
#       Price was                                          Photo URL  \
# 0            NA  https://marketplacer.imgix.net/d-/8G3ztNko8Xqr...
# 1        $8,900  https://marketplacer.imgix.net/N6/1TS1xDZay3tI...
# 2     $2,999.99  https://marketplacer.imgix.net/-Q/n60HKTmpOW9P...
# 3       $11,290  https://marketplacer.imgix.net/aC/sh5gatS79aaX...
# 4     $2,719.99  https://marketplacer.imgix.net/WP/tcSsaSkBikZg...
# ...         ...                                                ...
# 1977         NA  https://marketplacer.imgix.net/7r/cz2mmLOti9tO...
# 1978         NA  https://marketplacer.imgix.net/v5/fcHZp77E0US6...
# 1979         NA  https://marketplacer.imgix.net/Dx/oux56-XWvHUz...
# 1980         NA  https://marketplacer.imgix.net/I9/qZUoD45DDKFB...
# 1981         NA  https://marketplacer.imgix.net/_v/C5BKN6LeRFpM...
#
#             Brand                            Type             Color  \
# 0      Cannondale  Full Suspension Mountain Bikes            Yellow
# 1     Specialized  Full Suspension Mountain Bikes       Matte Black
# 2           Giant  Full Suspension Mountain Bikes             Green
# 3      Cannondale  Full Suspension Mountain Bikes             Black
# 4            Haro  Full Suspension Mountain Bikes               NaN
# ...           ...                             ...               ...
# 1977  Specialized                      Road Bikes  Black, Navy Blue
# 1978      Bianchi                      Road Bikes           Celeste
# 1979   Cannondale                      Road Bikes             Black
# 1980          KHS                      Road Bikes       Matte Black
# 1981    Pinarello                      Road Bikes            Yellow
#
#      Frame in inches                                 Size  ...   Riding Style  \
# 0                21"                                Large  ...         Enduro
# 1                17"                               Medium  ...         Enduro
# 2                20"                                Large  ...  Cross Country
# 3           17", 19"                        Medium, Large  ...          Trail
# 4                NaN                                  NaN  ...          Trail
# ...              ...                                  ...  ...            ...
# 1977             NaN    XS, Small, Medium, Large, XL, XXL  ...            NaN
# 1978             NaN  Small, Medium, Large, XL, XXL, XXXL  ...            NaN
# 1979             NaN                                Small  ...            NaN
# 1980             NaN                                   XS  ...            NaN
# 1981             NaN  XS/S, Small, Medium, Large, XL, XXL  ...            NaN
#
#                     Material Wheel Size Rear Derailleur Item condition  \
# 0                     Carbon      27.5"  SRAM X01 Eagle           Used
# 1                   Aluminum        29"         SRAM GX            New
# 2                     Carbon      27.5"     Shimano SLX            New
# 3                     Carbon      27.5"        SRAM XX1            New
# 4                   Aluminum      27.5"      Shimano XT            New
# ...                      ...        ...             ...            ...
# 1977                  Carbon        NaN             NaN            New
# 1978                  Carbon        NaN             NaN            New
# 1979                  Carbon        NaN             NaN            New
# 1980  Carbon Alloy Composite        NaN             NaN            New
# 1981                  Carbon        NaN             NaN            New
#
#                     Availability         ID  \
# 0                     Private ad  184072403
# 1                       In-store  134527719
# 2                       In-store  145165237
# 3                       In-store  100011220
# 4     Pick Up In Store, In-store  134718360
# ...                          ...        ...
# 1977                    In-store  177850247
# 1978                    In-store  146255978
# 1979                    In-store  102758886
# 1980                    In-store  113091120
# 1981                    In-store  122324148
#
#                                  Size CM             Groupset Braking Type
# 0                                    NaN                  NaN          NaN
# 1                                    NaN                  NaN          NaN
# 2                                    NaN                  NaN          NaN
# 3                                    NaN                  NaN          NaN
# 4                                    NaN                  NaN          NaN
# ...                                  ...                  ...          ...
# 1977  49cm, 52cm, 54cm, 56cm, 58cm, 61cm  Shimano Ultegra Di2  Disc Brakes
# 1978  50cm, 53cm, 55cm, 57cm, 59cm, 61cm          Shimano 105   Rim Brakes
# 1979                                51cm          Shimano 105   Rim Brakes
# 1980                                49cm      Shimano Ultegra   Rim Brakes
# 1981  50cm, 52cm, 54cm, 56cm, 58cm, 60cm                  N/A   Rim Brakes
#
# [1982 rows x 21 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.reset_option('all')
# Out:
# C:\Users\Szymon\AppData\Local\Temp\ipykernel_20828\954186090.py:3: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')

# %%
df[['Type', 'Riding Style']][df['Type'].str.contains('Road')].head(10)
# Out:
#             Type Riding Style
# 1000  Road Bikes          NaN
# 1001  Road Bikes          NaN
# 1002  Road Bikes          NaN
# 1003  Road Bikes          NaN
# 1004  Road Bikes          NaN
# 1005  Road Bikes          NaN
# 1006  Road Bikes          NaN
# 1007  Road Bikes          NaN
# 1008  Road Bikes          NaN
# 1009  Road Bikes          NaN

# %%
def print_nans_perc(df):
    n = len(df)
    nans_perc = ((df.isna().sum() / n) * 100).sort_values(ascending=True)
    print('len - ', n)
    for index, val in zip(nans_perc.index, nans_perc):
        print(index + ': ', val)
print_nans_perc(df)
# Out:
# len -  1982
# Title:  0.0
# Product URL:  0.0
# Price now:  0.0
# Price was:  0.0
# Photo URL:  0.0
# Brand:  0.0
# Type:  0.0
# ID:  0.0
# Availability:  0.0
# Item condition:  0.0
# Material:  0.10090817356205853
# Gender:  1.160443995963673
# Size:  17.658930373360242
# Color:  17.658930373360242
# Wheel Size:  49.6468213925328
# Rear Derailleur:  49.6468213925328
# Riding Style:  49.6468213925328
# Groupset:  50.45408678102926
# Braking Type:  50.45408678102926
# Frame in inches:  55.14631685166499
# Size CM:  62.66397578203835

# %%
bike_types = df['Type'].unique()
for Btype in bike_types:
    print('\n\n'+ Btype + ':\n')
    print_nans_perc(df[df['Type'] == Btype])
# Out:
# Full Suspension Mountain Bikes:
#
# len -  499
# Title:  0.0
# ID:  0.0
# Availability:  0.0
# Item condition:  0.0
# Rear Derailleur:  0.0
# Wheel Size:  0.0
# Material:  0.0
# Riding Style:  0.0
# Gender:  0.0
# Type:  0.0
# Brand:  0.0
# Photo URL:  0.0
# Price was:  0.0
# Price now:  0.0
# Product URL:  0.0
# Size:  14.629258517034069
# Color:  14.629258517034069
# Frame in inches:  14.829659318637276
# Groupset:  100.0
# Size CM:  100.0
# Braking Type:  100.0
#
#
# Hardtail Mountain Bikes:
#
# len -  478
# Title:  0.0
# ID:  0.0
# Availability:  0.0
# Item condition:  0.0
# Rear Derailleur:  0.0
# Wheel Size:  0.0
# Material:  0.0
# Riding Style:  0.0
# Gender:  0.0
# Type:  0.0
# Brand:  0.0
# Photo URL:  0.0
# Price was:  0.0
# Price now:  0.0
# Product URL:  0.0
# Size:  7.322175732217573
# Color:  7.322175732217573
# Frame in inches:  7.322175732217573
# Groupset:  100.0
# Size CM:  100.0
# Braking Type:  100.0
#
#
# Rigid Mountain Bikes:
#
# len -  21
# Title:  0.0
# Item condition:  0.0
# Rear Derailleur:  0.0
# Wheel Size:  0.0
# Material:  0.0
# Riding Style:  0.0
# Size:  0.0
# Availability:  0.0
# Frame in inches:  0.0
# Type:  0.0
# Brand:  0.0
# Photo URL:  0.0
# Price was:  0.0
# Price now:  0.0
# Product URL:  0.0
# Color:  0.0
# ID:  0.0
# Size CM:  100.0
# Gender:  100.0
# Groupset:  100.0
# Braking Type:  100.0
#
#
# Mountain Bikes:
#
# len -  2
# Title:  0.0
# Product URL:  0.0
# Price now:  0.0
# Price was:  0.0
# Photo URL:  0.0
# Brand:  0.0
# Type:  0.0
# Color:  0.0
# Size:  0.0
# ID:  0.0
# Availability:  0.0
# Item condition:  0.0
# Size CM:  100.0
# Rear Derailleur:  100.0
# Gender:  100.0
# Material:  100.0
# Riding Style:  100.0
# Groupset:  100.0
# Frame in inches:  100.0
# Wheel Size:  100.0
# Braking Type:  100.0
#
#
# Road Bikes:
#
# len -  982
# Title:  0.0
# ID:  0.0
# Availability:  0.0
# Item condition:  0.0
# Material:  0.0
# Groupset:  0.0
# Gender:  0.0
# Brand:  0.0
# Photo URL:  0.0
# Price was:  0.0
# Price now:  0.0
# Product URL:  0.0
# Type:  0.0
# Braking Type:  0.0
# Color:  24.643584521384927
# Size:  24.643584521384927
# Size CM:  24.643584521384927
# Frame in inches:  100.0
# Riding Style:  100.0
# Wheel Size:  100.0
# Rear Derailleur:  100.0

# %%
usefull_cols = ['ID','Title','Type','Price now','Brand','Item condition', 'Material', 'Rear Derailleur', 'Groupset', 'Braking Type']
usefull_cols_road = ['ID','Title','Price now','Brand','Item condition', 'Material', 'Groupset', 'Braking Type']

# %%
roadies_orig = df[df['Type'] == 'Road Bikes'][usefull_cols_road]
print_nans_perc(roadies_orig)
# Out:
# len -  982
# ID:  0.0
# Title:  0.0
# Price now:  0.0
# Brand:  0.0
# Item condition:  0.0
# Material:  0.0
# Groupset:  0.0
# Braking Type:  0.0

# %%
roadies = roadies_orig.copy()
roadies.rename(columns={'Price now': 'Price'}, inplace=True)
roadies['Price'].replace('[A-Za-z, \$]','',inplace=True, regex=True)
roadies = roadies[roadies['Price'] != '']
roadies['Price'] = roadies['Price'].astype(float)
roadies
# Out:
#              ID                                              Title    Price  \
# 1000  159821272        Co-Motion Ristretto Dura Ace 9000 55cm 2017  2700.00
# 1001  184704180  Pinarello Gan K Disk 2019, 53cm, ULTEGRA, (Car...  3100.00
# 1002  185644207       Highly Upgraded Eddy Merckx 2016 San Remo 76  6500.00
# 1003  185407126              Specialized 2019 S-Works Tarmac Disc   7000.00
# 1004  186307540  R ID E Fast   Specialized S Works Tarmac Sl6  ...  7400.00
# ...         ...                                                ...      ...
# 1977  177850247               Specialized Venge Pro Disc Udi2 2020  8000.00
# 1978  146255978                           Bianchi Intenso 105 2019  2200.00
# 1979  102758886              Cannondale Synaspe Carbon 5 105  2016  2099.99
# 1980  113091120            Flite 900 Xl Matte Blk 2017  KHS/Maxxis  3069.00
# 1981  122324148  Pinarello Dogma F10 Sulfur Yellow Custom Build...  7499.99
#
#             Brand Item condition                Material  \
# 1000    Co-Motion           Used                Aluminum
# 1001    Pinarello           Used                  Carbon
# 1002  Eddy Merckx           Used                  Carbon
# 1003  Specialized           Used                  Carbon
# 1004  Specialized           Used                  Carbon
# ...           ...            ...                     ...
# 1977  Specialized            New                  Carbon
# 1978      Bianchi            New                  Carbon
# 1979   Cannondale            New                  Carbon
# 1980          KHS            New  Carbon Alloy Composite
# 1981    Pinarello            New                  Carbon
#
#                   Groupset Braking Type
# 1000      Shimano Dura Ace   Rim Brakes
# 1001       Shimano Ultegra  Disc Brakes
# 1002   Shimano Ultegra Di2  Disc Brakes
# 1003   Shimano Ultegra Di2  Disc Brakes
# 1004  Shimano Dura Ace Di2  Disc Brakes
# ...                    ...          ...
# 1977   Shimano Ultegra Di2  Disc Brakes
# 1978           Shimano 105   Rim Brakes
# 1979           Shimano 105   Rim Brakes
# 1980       Shimano Ultegra   Rim Brakes
# 1981                   N/A   Rim Brakes
#
# [980 rows x 8 columns]

# %%
roadies.rename(columns={'Item condition': 'isNew'}, inplace=True)
roadies['isNew'].replace({'Used': 0, 'New': 1},inplace=True, regex=True)
roadies['isNew'] = roadies['isNew'].astype(int)
roadies
# Out:
#              ID                                              Title    Price  \
# 1000  159821272        Co-Motion Ristretto Dura Ace 9000 55cm 2017  2700.00
# 1001  184704180  Pinarello Gan K Disk 2019, 53cm, ULTEGRA, (Car...  3100.00
# 1002  185644207       Highly Upgraded Eddy Merckx 2016 San Remo 76  6500.00
# 1003  185407126              Specialized 2019 S-Works Tarmac Disc   7000.00
# 1004  186307540  R ID E Fast   Specialized S Works Tarmac Sl6  ...  7400.00
# ...         ...                                                ...      ...
# 1977  177850247               Specialized Venge Pro Disc Udi2 2020  8000.00
# 1978  146255978                           Bianchi Intenso 105 2019  2200.00
# 1979  102758886              Cannondale Synaspe Carbon 5 105  2016  2099.99
# 1980  113091120            Flite 900 Xl Matte Blk 2017  KHS/Maxxis  3069.00
# 1981  122324148  Pinarello Dogma F10 Sulfur Yellow Custom Build...  7499.99
#
#             Brand  isNew                Material              Groupset  \
# 1000    Co-Motion      0                Aluminum      Shimano Dura Ace
# 1001    Pinarello      0                  Carbon       Shimano Ultegra
# 1002  Eddy Merckx      0                  Carbon   Shimano Ultegra Di2
# 1003  Specialized      0                  Carbon   Shimano Ultegra Di2
# 1004  Specialized      0                  Carbon  Shimano Dura Ace Di2
# ...           ...    ...                     ...                   ...
# 1977  Specialized      1                  Carbon   Shimano Ultegra Di2
# 1978      Bianchi      1                  Carbon           Shimano 105
# 1979   Cannondale      1                  Carbon           Shimano 105
# 1980          KHS      1  Carbon Alloy Composite       Shimano Ultegra
# 1981    Pinarello      1                  Carbon                   N/A
#
#      Braking Type
# 1000   Rim Brakes
# 1001  Disc Brakes
# 1002  Disc Brakes
# 1003  Disc Brakes
# 1004  Disc Brakes
# ...           ...
# 1977  Disc Brakes
# 1978   Rim Brakes
# 1979   Rim Brakes
# 1980   Rim Brakes
# 1981   Rim Brakes
#
# [980 rows x 8 columns]

# %%
material_dict = {'Chromoly': 0.15, 'Steel': 0.3, 'Aluminum': 0.45, 'Titanium': 0.6, 'Carbon Alloy Composite': 0.75, 'Carbon': 0.9}
roadies['material_num'] = roadies['Material'].replace(material_dict, regex=True)
roadies['material_num'] = roadies['material_num'].astype(float)
roadies
# Out:
#              ID                                              Title    Price  \
# 1000  159821272        Co-Motion Ristretto Dura Ace 9000 55cm 2017  2700.00
# 1001  184704180  Pinarello Gan K Disk 2019, 53cm, ULTEGRA, (Car...  3100.00
# 1002  185644207       Highly Upgraded Eddy Merckx 2016 San Remo 76  6500.00
# 1003  185407126              Specialized 2019 S-Works Tarmac Disc   7000.00
# 1004  186307540  R ID E Fast   Specialized S Works Tarmac Sl6  ...  7400.00
# ...         ...                                                ...      ...
# 1977  177850247               Specialized Venge Pro Disc Udi2 2020  8000.00
# 1978  146255978                           Bianchi Intenso 105 2019  2200.00
# 1979  102758886              Cannondale Synaspe Carbon 5 105  2016  2099.99
# 1980  113091120            Flite 900 Xl Matte Blk 2017  KHS/Maxxis  3069.00
# 1981  122324148  Pinarello Dogma F10 Sulfur Yellow Custom Build...  7499.99
#
#             Brand  isNew                Material              Groupset  \
# 1000    Co-Motion      0                Aluminum      Shimano Dura Ace
# 1001    Pinarello      0                  Carbon       Shimano Ultegra
# 1002  Eddy Merckx      0                  Carbon   Shimano Ultegra Di2
# 1003  Specialized      0                  Carbon   Shimano Ultegra Di2
# 1004  Specialized      0                  Carbon  Shimano Dura Ace Di2
# ...           ...    ...                     ...                   ...
# 1977  Specialized      1                  Carbon   Shimano Ultegra Di2
# 1978      Bianchi      1                  Carbon           Shimano 105
# 1979   Cannondale      1                  Carbon           Shimano 105
# 1980          KHS      1  Carbon Alloy Composite       Shimano Ultegra
# 1981    Pinarello      1                  Carbon                   N/A
#
#      Braking Type  material_num
# 1000   Rim Brakes          0.45
# 1001  Disc Brakes          0.90
# 1002  Disc Brakes          0.90
# 1003  Disc Brakes          0.90
# 1004  Disc Brakes          0.90
# ...           ...           ...
# 1977  Disc Brakes          0.90
# 1978   Rim Brakes          0.90
# 1979   Rim Brakes          0.90
# 1980   Rim Brakes          0.75
# 1981   Rim Brakes          0.90
#
# [980 rows x 9 columns]

# %%
roadies.groupby('Groupset').size()
# Out:
# Groupset
# Campagnolo Centaur           1
# Campagnolo Chorus            2
# Campagnolo Super Record      2
# Campagnolo Veloce            1
# N/A                         11
# SRAM Apex                    7
# SRAM Force                  21
# SRAM Force AXS               1
# SRAM Red                     8
# SRAM Red AXS                 1
# SRAM Red eTap               51
# SRAM Rival                   1
# Shimano 105                255
# Shimano A070                11
# Shimano Claris              54
# Shimano Dura Ace            48
# Shimano Dura Ace Di2        35
# Shimano GRX                  2
# Shimano R2300                1
# Shimano R460                 1
# Shimano Sora                56
# Shimano Tiagra              77
# Shimano Tourney              1
# Shimano Ultegra            209
# Shimano Ultegra Di2        121
# Shimano XTR Di2              2
# dtype: int64

# %%
roadies = roadies[roadies['Groupset'] != 'N/A']
roadies['e_shift_num'] = roadies['Groupset'].apply(lambda x: 1 if any(ele in x for ele in ['Di2', 'AXS', 'eTap']) else 0)

gropset_dict = {'Campagnolo Veloce': 0.7,'Campagnolo Centaur': 0.8, 'Campagnolo Chorus': 0.9, 'Campagnolo Super Record': 1,
       'SRAM Apex': 0.6, 'SRAM Rival': 0.7, 'SRAM Force': 0.8, 'SRAM Red': 0.9,  
       'SRAM Force AXS': 0.85, 'SRAM Red AXS': 1, 'SRAM Red eTap': 1,
       'Shimano Tourney': 0.3, 'Shimano Claris': 0.4, 'Shimano Sora': 0.5,'Shimano Tiagra': 0.6, 'Shimano 105': 0.7,'Shimano Ultegra': 0.8, 'Shimano Dura Ace': 0.9,
       'Shimano XTR Di2': 1, 'Shimano Ultegra Di2': 0.85 ,'Shimano Dura Ace Di2': 1, 
       'Shimano A070': 0.3, 'Shimano GRX': 0.7, 'Shimano R2300': 0.3 , 'Shimano R460': 0.3,
       }
roadies['groupset_num'] = roadies['Groupset'].replace(gropset_dict, regex=True, inplace=False)
roadies
# Out:
# C:\Users\Szymon\AppData\Local\Temp\ipykernel_20828\2890023513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   roadies['e_shift_num'] = roadies['Groupset'].apply(lambda x: 1 if any(ele in x for ele in ['Di2', 'AXS', 'eTap']) else 0)
# C:\Users\Szymon\AppData\Local\Temp\ipykernel_20828\2890023513.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   roadies['groupset_num'] = roadies['Groupset'].replace(gropset_dict, regex=True, inplace=False)
#              ID                                              Title    Price  \
# 1000  159821272        Co-Motion Ristretto Dura Ace 9000 55cm 2017  2700.00
# 1001  184704180  Pinarello Gan K Disk 2019, 53cm, ULTEGRA, (Car...  3100.00
# 1002  185644207       Highly Upgraded Eddy Merckx 2016 San Remo 76  6500.00
# 1003  185407126              Specialized 2019 S-Works Tarmac Disc   7000.00
# 1004  186307540  R ID E Fast   Specialized S Works Tarmac Sl6  ...  7400.00
# ...         ...                                                ...      ...
# 1976  113790485                               Scott Addict 15 2016  3999.99
# 1977  177850247               Specialized Venge Pro Disc Udi2 2020  8000.00
# 1978  146255978                           Bianchi Intenso 105 2019  2200.00
# 1979  102758886              Cannondale Synaspe Carbon 5 105  2016  2099.99
# 1980  113091120            Flite 900 Xl Matte Blk 2017  KHS/Maxxis  3069.00
#
#             Brand  isNew                Material              Groupset  \
# 1000    Co-Motion      0                Aluminum      Shimano Dura Ace
# 1001    Pinarello      0                  Carbon       Shimano Ultegra
# 1002  Eddy Merckx      0                  Carbon   Shimano Ultegra Di2
# 1003  Specialized      0                  Carbon   Shimano Ultegra Di2
# 1004  Specialized      0                  Carbon  Shimano Dura Ace Di2
# ...           ...    ...                     ...                   ...
# 1976        Scott      1  Carbon Alloy Composite       Shimano Ultegra
# 1977  Specialized      1                  Carbon   Shimano Ultegra Di2
# 1978      Bianchi      1                  Carbon           Shimano 105
# 1979   Cannondale      1                  Carbon           Shimano 105
# 1980          KHS      1  Carbon Alloy Composite       Shimano Ultegra
#
#      Braking Type  material_num  e_shift_num  groupset_num
# 1000   Rim Brakes          0.45            0           0.9
# 1001  Disc Brakes          0.90            0           0.8
# 1002  Disc Brakes          0.90            1           0.8
# 1003  Disc Brakes          0.90            1           0.8
# 1004  Disc Brakes          0.90            1           0.9
# ...           ...           ...          ...           ...
# 1976   Rim Brakes          0.75            0           0.8
# 1977  Disc Brakes          0.90            1           0.8
# 1978   Rim Brakes          0.90            0           0.7
# 1979   Rim Brakes          0.90            0           0.7
# 1980   Rim Brakes          0.75            0           0.8
#
# [969 rows x 11 columns]

# %%
roadies.rename(columns={'Braking Type': 'brake_num'}, inplace=True)
roadies['brake_num'].replace({'Disc Brakes': 1, 'Rim Brakes': 0.5}, inplace=True, regex=True)
roadies
# Out:
# C:\Users\Szymon\AppData\Local\Temp\ipykernel_20828\3843223646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   roadies.rename(columns={'Braking Type': 'brake_num'}, inplace=True)
# C:\Users\Szymon\AppData\Local\Temp\ipykernel_20828\3843223646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   roadies['brake_num'].replace({'Disc Brakes': 1, 'Rim Brakes': 0.5}, inplace=True, regex=True)
#              ID                                              Title    Price  \
# 1000  159821272        Co-Motion Ristretto Dura Ace 9000 55cm 2017  2700.00
# 1001  184704180  Pinarello Gan K Disk 2019, 53cm, ULTEGRA, (Car...  3100.00
# 1002  185644207       Highly Upgraded Eddy Merckx 2016 San Remo 76  6500.00
# 1003  185407126              Specialized 2019 S-Works Tarmac Disc   7000.00
# 1004  186307540  R ID E Fast   Specialized S Works Tarmac Sl6  ...  7400.00
# ...         ...                                                ...      ...
# 1976  113790485                               Scott Addict 15 2016  3999.99
# 1977  177850247               Specialized Venge Pro Disc Udi2 2020  8000.00
# 1978  146255978                           Bianchi Intenso 105 2019  2200.00
# 1979  102758886              Cannondale Synaspe Carbon 5 105  2016  2099.99
# 1980  113091120            Flite 900 Xl Matte Blk 2017  KHS/Maxxis  3069.00
#
#             Brand  isNew                Material              Groupset  \
# 1000    Co-Motion      0                Aluminum      Shimano Dura Ace
# 1001    Pinarello      0                  Carbon       Shimano Ultegra
# 1002  Eddy Merckx      0                  Carbon   Shimano Ultegra Di2
# 1003  Specialized      0                  Carbon   Shimano Ultegra Di2
# 1004  Specialized      0                  Carbon  Shimano Dura Ace Di2
# ...           ...    ...                     ...                   ...
# 1976        Scott      1  Carbon Alloy Composite       Shimano Ultegra
# 1977  Specialized      1                  Carbon   Shimano Ultegra Di2
# 1978      Bianchi      1                  Carbon           Shimano 105
# 1979   Cannondale      1                  Carbon           Shimano 105
# 1980          KHS      1  Carbon Alloy Composite       Shimano Ultegra
#
#       brake_num  material_num  e_shift_num  groupset_num
# 1000        0.5          0.45            0           0.9
# 1001        1.0          0.90            0           0.8
# 1002        1.0          0.90            1           0.8
# 1003        1.0          0.90            1           0.8
# 1004        1.0          0.90            1           0.9
# ...         ...           ...          ...           ...
# 1976        0.5          0.75            0           0.8
# 1977        1.0          0.90            1           0.8
# 1978        0.5          0.90            0           0.7
# 1979        0.5          0.90            0           0.7
# 1980        0.5          0.75            0           0.8
#
# [969 rows x 11 columns]

# %%
import re

def find_year(x):
    four_num = re.findall(r'[0-9]{4}', x)
    four_num = [int(num) for num in four_num]
    for num in four_num:
        if 1990 <= num <= 2024:
            return num
    return np.nan

roadies['Production_year'] = roadies['Title'].apply(find_year)
roadies['Production_year'].fillna(roadies['Production_year'].median(), inplace=True)
roadies['Production_year']
# Out:
# C:\Users\Szymon\AppData\Local\Temp\ipykernel_20828\2942446799.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   roadies['Production_year'] = roadies['Title'].apply(find_year)
# C:\Users\Szymon\AppData\Local\Temp\ipykernel_20828\2942446799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   roadies['Production_year'].fillna(roadies['Production_year'].median(), inplace=True)
# 1000    2017.0
# 1001    2019.0
# 1002    2016.0
# 1003    2019.0
# 1004    2019.0
#          ...
# 1976    2016.0
# 1977    2020.0
# 1978    2019.0
# 1979    2016.0
# 1980    2017.0
# Name: Production_year, Length: 969, dtype: float64

# %%
num_cols = ['ID', 'Price','Production_year', 'isNew', 'material_num', 'groupset_num', 'e_shift_num', 'brake_num']

# %%
roadies_num = roadies[num_cols]
roadies_num.to_json('..\data\\num_data\exch_road.json', lines=True, orient='records')
roadies_num
# Out:
#              ID    Price  Production_year  isNew  material_num  groupset_num  \
# 1000  159821272  2700.00           2017.0      0          0.45           0.9
# 1001  184704180  3100.00           2019.0      0          0.90           0.8
# 1002  185644207  6500.00           2016.0      0          0.90           0.8
# 1003  185407126  7000.00           2019.0      0          0.90           0.8
# 1004  186307540  7400.00           2019.0      0          0.90           0.9
# ...         ...      ...              ...    ...           ...           ...
# 1976  113790485  3999.99           2016.0      1          0.75           0.8
# 1977  177850247  8000.00           2020.0      1          0.90           0.8
# 1978  146255978  2200.00           2019.0      1          0.90           0.7
# 1979  102758886  2099.99           2016.0      1          0.90           0.7
# 1980  113091120  3069.00           2017.0      1          0.75           0.8
#
#       e_shift_num  brake_num
# 1000            0        0.5
# 1001            0        1.0
# 1002            1        1.0
# 1003            1        1.0
# 1004            1        1.0
# ...           ...        ...
# 1976            0        0.5
# 1977            1        1.0
# 1978            0        0.5
# 1979            0        0.5
# 1980            0        0.5
#
# [969 rows x 8 columns]
